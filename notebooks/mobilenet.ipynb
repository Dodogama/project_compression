# %%
import torchvision.models as models

# Load the pre-trained MobileNetV3 Large model
model_large = models.mobilenet_v3_large(pretrained=True)

# Print the model architecture
print("\nMobileNetV3 Large Architecture:")
print(model_large)

model_small = models.mobilenet_v3_small(pretrained=False)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ece_ml_env/lib/python3.11/site-packages/torchvision/io/image.py:14: UserWarning: Failed to load image Python extension: 'dlopen(/opt/homebrew/Caskroom/miniforge/base/envs/ece_ml_env/lib/python3.11/site-packages/torchvision/image.so, 0x0006): Library not loaded: @rpath/libjpeg.9.dylib
#   Referenced from: <EB3FF92A-5EB1-3EE8-AF8B-5923C1265422> /opt/homebrew/Caskroom/miniforge/base/envs/ece_ml_env/lib/python3.11/site-packages/torchvision/image.so
# ...

# %%
import os
import sys
project_dir = os.path.dirname(os.getcwd())
sys.path.append(project_dir)

# %%
from utils.summary import get_model_stats

# Define the input size that the model expects
# For typical image classification tasks, it's often (3, 224, 224)
input_size = (3, 224, 224)

# Use the get_model_stats function on model_small
stats_small = get_model_stats(model_small, input_size)

if stats_small:
    print("MobileNetV3 Small Statistics:")
    print(f"  FLOPs: {stats_small['flops']:.2f}")
    print(f"  Parameters: {stats_small['params']:,}")
else:
    print("Could not retrieve statistics for MobileNetV3 Small.")
# Out:
# Error calculating FLOPs: Failed to run torchinfo. See above stack traces for more details. Executed layers up to: [Conv2d: 3]
# Could not retrieve statistics for MobileNetV3 Small.

# %%
# note batch size and input shape influence FLOPS and params
sample = torch.randn(16, 3, 32, 32).to(device)
with torch.no_grad():
    print("Teacher model stats:")
    pred = teacher(sample)
    for name, param in get_model_stats(teacher, sample.shape).items():
        print(f"{name}: {param}")
    print("Student model stats:")
    pred = teacher(sample)
    for name, param in get_model_stats(student, sample.shape).items():
        print(f"{name}: {param}")
